# %% [markdown]
# # Быстрый старт в анализ данных
# с помощью Pandas и Scikit-learn, а также numpy и matplotlib
#
# matplotlib – научная графика\
# pandas – таблицы (DataFrame) для анализа данных\
# scikit-learn – алгоритмы машинного обучения\

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# Подгружаем файл

# %%
#url = 'https://www.kaggle.com/austinreese/craigslist-carstrucks-data'
#data = pd.read_csv(url, sep = ', ', engine='python')
data = pd.read_csv('../source/craigslistVehiclesFull.csv', engine = 'python')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Смотрим на таблицу

# %%
data
# Out:
#                                                        url      city  price  \
# 0        https://marshall.craigslist.org/cto/d/2010-dod...  marshall  11900
# 1        https://marshall.craigslist.org/cto/d/fleetwoo...  marshall   1515
# 2        https://marshall.craigslist.org/cto/d/2008-for...  marshall  17550
# 3        https://marshall.craigslist.org/cto/d/ford-tau...  marshall   2800
# 4        https://marshall.craigslist.org/cto/d/2001-gra...  marshall    400
# 5        https://marshall.craigslist.org/ctd/d/2007-gmc...  marshall   9900
# 6        https://marshall.craigslist.org/cto/d/2015-jee...  marshall  12500
# 7        https://marshall.craigslist.org/ctd/d/2008-bmw...  marshall   3900
# 8        https://soo.craigslist.ca/cto/d/ebike-red-zone...       soo   2700
# 9        https://soo.craigslist.ca/ctd/d/2003-ford-excu...       soo  12995
# 10       https://soo.craigslist.ca/cto/d/2006-chev-expr...       soo   4000
# ...

# %%
print(data)
# Out:
#                                                        url      city  price  \
# 0        https://marshall.craigslist.org/cto/d/2010-dod...  marshall  11900
# 1        https://marshall.craigslist.org/cto/d/fleetwoo...  marshall   1515
# 2        https://marshall.craigslist.org/cto/d/2008-for...  marshall  17550
# 3        https://marshall.craigslist.org/cto/d/ford-tau...  marshall   2800
# 4        https://marshall.craigslist.org/cto/d/2001-gra...  marshall    400
# 5        https://marshall.craigslist.org/ctd/d/2007-gmc...  marshall   9900
# 6        https://marshall.craigslist.org/cto/d/2015-jee...  marshall  12500
# 7        https://marshall.craigslist.org/ctd/d/2008-bmw...  marshall   3900
# 8        https://soo.craigslist.ca/cto/d/ebike-red-zone...       soo   2700
# 9        https://soo.craigslist.ca/ctd/d/2003-ford-excu...       soo  12995
# 10       https://soo.craigslist.ca/cto/d/2006-chev-expr...       soo   4000
# ...

# %%
#data.columns = [u'url', u'city', u'price', u'year', u'manufacturer',
#       u'make', u'condition', u'cylinders', u'fuel', u'odometer',
#       u'paint_color', u'image_url', u'lat', u'long',
#       u'county_fips']

# %%
data.head()
# Out:
#                                                  url      city  price    year  \
# 0  https://marshall.craigslist.org/cto/d/2010-dod...  marshall  11900  2010.0
# 1  https://marshall.craigslist.org/cto/d/fleetwoo...  marshall   1515  1999.0
# 2  https://marshall.craigslist.org/cto/d/2008-for...  marshall  17550  2008.0
# 3  https://marshall.craigslist.org/cto/d/ford-tau...  marshall   2800  2004.0
# 4  https://marshall.craigslist.org/cto/d/2001-gra...  marshall    400  2001.0
#
#   manufacturer             make condition    cylinders fuel  odometer  ...  \
# 0        dodge    challenger se      good  6 cylinders  gas   43600.0  ...
# 1          NaN        fleetwood       NaN          NaN  gas       NaN  ...
# 2         ford            f-150       NaN          NaN  gas       NaN  ...
# 3         ford           taurus      good  6 cylinders  gas  168591.0  ...
# 4          NaN  2001 Grand Prix       NaN          NaN  gas  217000.0  ...
#
# ...

# %%
data.tail()
# Out:
#                                                        url      city  price  \
# 1723060  https://marshall.craigslist.org/cto/d/05-toyot...  marshall   8450
# 1723061  https://marshall.craigslist.org/cto/d/2005-che...  marshall   6000
# 1723062  https://marshall.craigslist.org/ctd/d/2007-vol...  marshall   1500
# 1723063  https://marshall.craigslist.org/cto/d/toyota-c...  marshall   4788
# 1723064  https://marshall.craigslist.org/cto/d/1980-lin...  marshall   2000
#
#            year manufacturer         make condition    cylinders fuel  \
# 1723060  2005.0          NaN         NICE  like new  8 cylinders  gas
# 1723061  2005.0        chevy    avalanche      good  8 cylinders  gas
# 1723062  2007.0   volkswagen  jetta sedan       NaN          NaN  gas
# 1723063  2009.0       toyota        camry      good  4 cylinders  gas
# 1723064  1980.0      lincoln  continental      good  8 cylinders  gas
#
#          odometer  ... paint_color  \
# 1723060  162000.0  ...         NaN
# ...

# %%
data.shape
# Out:
# (1723065, 26)

# %%
data.columns
# Out:
# Index(['url', 'city', 'price', 'year', 'manufacturer', 'make', 'condition',
#        'cylinders', 'fuel', 'odometer', 'title_status', 'transmission', 'vin',
#        'drive', 'size', 'type', 'paint_color', 'image_url', 'lat', 'long',
#        'county_fips', 'county_name', 'state_fips', 'state_code', 'state_name',
#        'weather'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1723065 entries, 0 to 1723064
# Data columns (total 26 columns):
# url             object
# city            object
# price           int64
# year            float64
# manufacturer    object
# make            object
# condition       object
# cylinders       object
# fuel            object
# odometer        float64
# title_status    object
# transmission    object
# vin             object
# drive           object
# size            object
# type            object
# paint_color     object
# image_url       object
# lat             float64
# long            float64
# county_fips     float64
# county_name     object
# state_fips      float64
# state_code      object
# state_name      object
# weather         float64
# dtypes: float64(7), int64(1), object(18)
# memory usage: 341.8+ MB

# %% [markdown]
# Описание данных:
#   *  url - ссылка на автомобиль\
#   *  city - город, в котором находится автомобиль\
#   *  price - цена автомобиля\
#   *  year - год выпуска автомобиля\
#   *  manufacturer - марка автомобиля\
#   *  make - модель автомобиля\
#   *  condition - состояние автомобиля\
#   *  cylinders - количество цилиндров\
#   *  fuel - тип топлива\
#   *  odometer - пробег\
#   *  title-status - права собственности\
#   *  transmission - тип коробки передач\
#   *  vin - вин код автомобиля\
#   *  drive - тип привод \
#   *  size - тип размера автомобиля\
#   *  type - тип автомобиля\
#   *  paint_color - цвет автомобиля\
#   *  image_url - ссылка за изображение автомобиля\
#   *  lat - ширина автомобиля\
#   *  long - длина автомобиля\
#   *  county_fips - номер в федеральных стандартах обработки информации\
#   *  county_name - страна\
#   *  state_fips - номер штата\
#   *  state_name - название штата\
#   *  weather - климатическая установка для автомобиля\

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1723065, step=1)

# %%
data.at[2, 'price']
# Out:
# 17550

# %%
data['price']
# Out:
# 0          11900
# 1           1515
# 2          17550
# 3           2800
# 4            400
# 5           9900
# 6          12500
# 7           3900
# 8           2700
# 9          12995
# 10          4000
# 11         13000
# 12         21695
# 13         18000
# 14         29000
# 15          4500
# 16          9865
# 17         41896
# 18         44678
# 19         32546
# 20         30678
# 21         26500
# 22         31658
# 23         25997
# 24         26657
# 25         33678
# 26         31897
# 27         11423
# 28         23411
# 29         24896
#            ...
# 1723035     9500
# 1723036    11000
# 1723037     3800
# 1723038    13999
# 1723039    22999
# 1723040     1600
# 1723041    70999
# 1723042     5000
# 1723043     4500
# 1723044    13500
# 1723045     7000
# 1723046     2900
# 1723047     5200
# 1723048    12500
# 1723049    18900
# 1723050     6995
# 1723051     7500
# 1723052     2900
# 1723053     3000
# 1723054     1850
# 1723055     4000
# ...

# %%
data['price'][4]
# Out:
# 400

# %%
data['price'].dtype.name
# Out:
# 'int64'

# %%
type(data['price'][4])
# Out:
# numpy.int64

# %%
type(data['price'])
# Out:
# pandas.core.series.Series

# %%
data[['price', 'city']].head()
# Out:
#    price      city
# 0  11900  marshall
# 1   1515  marshall
# 2  17550  marshall
# 3   2800  marshall
# 4    400  marshall

# %%
plt.plot(data['year'], data['price'], 'o', alpha = 0.05)
plt.xlabel('year')
plt.ylabel('price')
plt.title('Year vs Price')
pass

# %%
data['state_code'] == 'SD'
# Out:
# 0           True
# 1           True
# 2           True
# 3          False
# 4          False
# 5           True
# 6           True
# 7          False
# 8          False
# 9          False
# 10         False
# 11         False
# 12         False
# 13         False
# 14         False
# 15         False
# 16         False
# 17         False
# 18         False
# 19         False
# 20         False
# 21         False
# 22         False
# 23         False
# 24         False
# 25         False
# 26         False
# 27         False
# 28         False
# 29         False
#            ...
# 1723035    False
# 1723036    False
# 1723037    False
# 1723038    False
# 1723039    False
# 1723040    False
# 1723041    False
# 1723042    False
# 1723043    False
# 1723044    False
# 1723045    False
# 1723046    False
# 1723047    False
# 1723048    False
# 1723049    False
# 1723050    False
# 1723051     True
# 1723052     True
# 1723053    False
# 1723054    False
# 1723055    False
# ...

# %%
data.describe()
# Out:
#               price          year      odometer           lat          long  \
# count  1.723065e+06  1.716750e+06  1.159011e+06  1.723065e+06  1.723065e+06
# mean   1.075540e+05  2.004841e+03  1.136387e+05  3.878195e+01 -9.371198e+01
# std    1.004439e+07  1.208772e+01  1.368603e+05  5.976412e+00  1.696519e+01
# min    1.000000e+00  3.020000e+02  0.000000e+00 -8.481005e+01 -1.000000e+03
# 25%    3.295000e+03  2.002000e+03  5.800000e+04  3.491900e+01 -1.058010e+02
# 50%    7.000000e+03  2.007000e+03  1.070000e+05  3.940989e+01 -8.824070e+01
# 75%    1.499900e+04  2.012000e+03  1.520000e+05  4.255459e+01 -8.102650e+01
# max    2.068627e+09  2.019000e+03  1.000000e+07  9.000000e+01  1.397061e+02
#
#         county_fips    state_fips       weather
# count  1.664232e+06  1.664232e+06  1.663637e+06
# mean   2.843053e+04  2.834410e+01  5.378706e+01
# std    1.605423e+04  1.603224e+01  7.799381e+00
# min    1.001000e+03  1.000000e+00  2.900000e+01
# ...

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data, alpha = .01, figsize = (10, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FED4FFD5F8>,
# ...
#       dtype=object)

# %%
data.corr()
# Out:
#                 price      year  odometer       lat      long  county_fips  \
# price        1.000000 -0.007597 -0.000356 -0.003327  0.001323     0.000861
# year        -0.007597  1.000000 -0.178321  0.019636 -0.036746     0.004942
# odometer    -0.000356 -0.178321  1.000000 -0.014029  0.040739     0.001307
# lat         -0.003327  0.019636 -0.014029  1.000000 -0.255507     0.210812
# long         0.001323 -0.036746  0.040739 -0.255507  1.000000     0.223538
# county_fips  0.000861  0.004942  0.001307  0.210812  0.223538     1.000000
# state_fips   0.000851  0.004820  0.001295  0.212324  0.223317     0.999982
# weather      0.002187  0.016031 -0.007273 -0.859342  0.036940    -0.155073
#
#              state_fips   weather
# price          0.000851  0.002187
# year           0.004820  0.016031
# odometer       0.001295 -0.007273
# lat            0.212324 -0.859342
# long           0.223317  0.036940
# county_fips    0.999982 -0.155073
# state_fips     1.000000 -0.156420
# ...

# %%
plt.figure(figsize = (10, 6))

plt.scatter(data[data['fuel'] == 'gas']['year'],
            data[data['fuel'] == 'gas']['price'],
            alpha = 0.15,
            label = 'gas',
            color = 'b')

plt.scatter(data[data['fuel'] == 'diesel']['year'],
            data[data['fuel'] == 'diesel']['price'],
            alpha = 0.05,
            label = 'diesel',
            color = 'r')
plt.scatter(data[data['fuel'] == 'electric']['year'],
            data[data['fuel'] == 'electric']['price'],
            alpha = 0.05,
            label = 'electric',
            color = 'g')
plt.xlabel('year')
plt.xticks(range(18))
plt.xlim(1900,2020)
plt.ylabel('price')
plt.legend()
plt.grid()

# %%
data.describe(include = ['object'])
# Out:
#                                                       url       city  \
# count                                             1723065    1723065
# unique                                            1723065        470
# top     https://springfieldil.craigslist.org/ctd/d/201...  cosprings
# freq                                                    1       8283
#
#        manufacturer     make  condition    cylinders     fuel title_status  \
# count       1586651  1653366    1022275      1031774  1712698      1720511
# unique           53   107445          6            8        5            6
# top            ford     1500  excellent  6 cylinders      gas        clean
# freq         292841    23346     443538       362142  1531426      1601315
#
#        transmission     vin    drive       size     type paint_color  \
# count       1714043  604850  1061181     599098  1020134     1027415
# unique            3  316208        3          4       13          12
# ...

# %%
data.describe(include = 'all')
# Out:
#                                                       url       city  \
# count                                             1723065    1723065
# unique                                            1723065        470
# top     https://springfieldil.craigslist.org/ctd/d/201...  cosprings
# freq                                                    1       8283
# mean                                                  NaN        NaN
# std                                                   NaN        NaN
# min                                                   NaN        NaN
# 25%                                                   NaN        NaN
# 50%                                                   NaN        NaN
# 75%                                                   NaN        NaN
# max                                                   NaN        NaN
#
#                price          year manufacturer     make  condition  \
# count   1.723065e+06  1.716750e+06      1586651  1653366    1022275
# ...

# %%
data['fuel'].unique()
# Out:
# array(['gas', 'electric', 'diesel', 'hybrid', 'other', nan], dtype=object)

# %%
data['city'].unique()
# Out:
# array(['marshall', 'soo', 'whistler', 'easttexas', 'skeena', 'lasvegas',
#        'hartford', 'reading', 'chambersburg', 'meadville', 'rapidcity',
#        'roseburg', 'orangecounty', 'rockford', 'hat', 'salina',
#        'lascruces', 'nd', 'allentown', 'csd', 'mattoon', 'humboldt',
#        'goldcountry', 'dothan', 'pittsburgh', 'lakecity', 'maine',
#        'charlotte', 'lewiston', 'cnj', 'wilmington', 'syracuse',
#        'columbia', 'tucson', 'asheville', 'providence', 'mcallen',
#        'butte', 'lakecharles', 'showlow', 'frederick', 'thumb', 'ogden',
#        'lethbridge', 'youngstown', 'erie', 'anchorage', 'yellowknife',
#        'appleton', 'springfieldil', 'glensfalls', 'norfolk', 'nh',
#        'sheboygan', 'yuma', 'cookeville', 'kenai', 'loz', 'plattsburgh',
#        'stlouis', 'brownsville', 'savannah', 'clovis', 'baltimore',
#        'kingston', 'roswell', 'spokane', 'battlecreek', 'boone', 'regina',
# ...

# %% [markdown]
# # Готовим данные

# %% [markdown]
# Разделим имеющиеся столбцы на категориальные и на числовые

# %%
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']
numerical_columns   = [c for c in data.columns if data[c].dtype.name != 'object']

# %%
categorical_columns
# Out:
# ['url',
#  'city',
#  'manufacturer',
#  'make',
#  'condition',
#  'cylinders',
#  'fuel',
#  'title_status',
#  'transmission',
#  'vin',
#  'drive',
#  'size',
#  'type',
#  'paint_color',
#  'image_url',
#  'county_name',
#  'state_code',
#  'state_name']

# %%
numerical_columns
# Out:
# ['price',
#  'year',
#  'odometer',
#  'lat',
#  'long',
#  'county_fips',
#  'state_fips',
#  'weather']

# %% [markdown]
# Найдем пропуски в числовых данных

# %%
data[numerical_columns].count(axis = 0)
# Out:
# price          1723065
# year           1716750
# odometer       1159011
# lat            1723065
# long           1723065
# county_fips    1664232
# state_fips     1664232
# weather        1663637
# dtype: int64

# %% [markdown]
# Найдем пропуски в категориальных данных

# %%
data[categorical_columns].count(axis = 0)
# Out:
# url             1723065
# city            1723065
# manufacturer    1586651
# make            1653366
# condition       1022275
# cylinders       1031774
# fuel            1712698
# title_status    1720511
# transmission    1714043
# vin              604850
# drive           1061181
# size             599098
# type            1020134
# paint_color     1027415
# image_url       1723064
# county_name     1664232
# state_code      1664232
# state_name      1723065
# dtype: int64

# %%
data.describe(include = [object])
# Out:
#                                                       url       city  \
# count                                             1723065    1723065
# unique                                            1723065        470
# top     https://springfieldil.craigslist.org/ctd/d/201...  cosprings
# freq                                                    1       8283
#
#        manufacturer     make  condition    cylinders     fuel title_status  \
# count       1586651  1653366    1022275      1031774  1712698      1720511
# unique           53   107445          6            8        5            6
# top            ford     1500  excellent  6 cylinders      gas        clean
# freq         292841    23346     443538       362142  1531426      1601315
#
#        transmission     vin    drive       size     type paint_color  \
# count       1714043  604850  1061181     599098  1020134     1027415
# unique            3  316208        3          4       13          12
# ...

# %%
data['fuel'].describe()
# Out:
# count     1712698
# unique          5
# top           gas
# freq      1531426
# Name: fuel, dtype: object

# %%
type(data['fuel'].describe())
# Out:
# pandas.core.series.Series

# %%
data['fuel'].describe().top
# Out:
# 'gas'

# %%
data['fuel'] = data['fuel'].fillna('gas')

# %%
data.describe(include = [object])
# Out:
#                                                       url       city  \
# count                                             1723065    1723065
# unique                                            1723065        470
# top     https://springfieldil.craigslist.org/ctd/d/201...  cosprings
# freq                                                    1       8283
#
#        manufacturer     make  condition    cylinders     fuel title_status  \
# count       1586651  1653366    1022275      1031774  1723065      1720511
# unique           53   107445          6            8        5            6
# top            ford     1500  excellent  6 cylinders      gas        clean
# freq         292841    23346     443538       362142  1541793      1601315
#
#        transmission     vin    drive       size     type paint_color  \
# count       1714043  604850  1061181     599098  1020134     1027415
# unique            3  316208        3          4       13          12
# ...

# %% [markdown]
# Метод заполнения пропусков во всех номинальных признаках наиболее часто встречаемыми значениями

# %%
data_describe = data.describe(include = [object])
for c in categorical_columns:
    data[c] = data[c].fillna(data_describe[c]['top'])

# %% [markdown]
# проверим заполнение данными

# %%
data.describe(include = [object])
# Out:
#                                                       url       city  \
# count                                             1723065    1723065
# unique                                            1723065        470
# top     https://springfieldil.craigslist.org/ctd/d/201...  cosprings
# freq                                                    1       8283
#
#        manufacturer     make  condition    cylinders     fuel title_status  \
# count       1723065  1723065    1723065      1723065  1723065      1723065
# unique           53   107445          6            8        5            6
# top            ford     1500  excellent  6 cylinders      gas        clean
# freq         429255    93045    1144328      1053433  1541793      1603869
#
#        transmission      vin    drive       size     type paint_color  \
# count       1723065  1723065  1723065    1723065  1723065     1723065
# unique            3   316208        3          4       13          12
# ...

# %%
data[categorical_columns].count(axis = 0)
# Out:
# url             1723065
# city            1723065
# manufacturer    1723065
# make            1723065
# condition       1723065
# cylinders       1723065
# fuel            1723065
# title_status    1723065
# transmission    1723065
# vin             1723065
# drive           1723065
# size            1723065
# type            1723065
# paint_color     1723065
# image_url       1723065
# county_name     1723065
# state_code      1723065
# state_name      1723065
# dtype: int64

# %%
data_categorical = data[categorical_columns]
data_categorical.describe()
# Out:
#                                                       url       city  \
# count                                             1723065    1723065
# unique                                            1723065        470
# top     https://springfieldil.craigslist.org/ctd/d/201...  cosprings
# freq                                                    1       8283
#
#        manufacturer     make  condition    cylinders     fuel title_status  \
# count       1723065  1723065    1723065      1723065  1723065      1723065
# unique           53   107445          6            8        5            6
# top            ford     1500  excellent  6 cylinders      gas        clean
# freq         429255    93045    1144328      1053433  1541793      1603869
#
#        transmission      vin    drive       size     type paint_color  \
# count       1723065  1723065  1723065    1723065  1723065     1723065
# unique            3   316208        3          4       13          12
# ...

# %% [markdown]
# Заполним пропущенные числовые значения медианными значениями

# %%
data.median(axis = 0)
# Out:
# price            7000.00000
# year             2007.00000
# odometer       107000.00000
# lat                39.40989
# long              -88.24070
# county_fips     29021.00000
# state_fips         29.00000
# weather            53.00000
# dtype: float64

# %%
data = data.fillna(data.median(axis = 0), axis = 0)

# %%
data[numerical_columns].count(axis = 0)
# Out:
# price          1723065
# year           1723065
# odometer       1723065
# lat            1723065
# long           1723065
# county_fips    1723065
# state_fips     1723065
# weather        1723065
# dtype: int64

# %% [markdown]
# # Нормализация количественных признаков
#
# Многие алгоритмы машинного обучения чувствительны к масштабированию данных. К таким алгоритмам, например, относится метод ближайших соседей, машина опорных векторов и др.
#
# В этом случае количественные признаки полезно нормализовать. Это можно делать разными способами. Например, каждый количественный признак приведем к нулевому среднему и единичному среднеквадратичному отклонению:

# %%
data_numerical = data[numerical_columns]
data_numerical.describe()
# Out:
#               price          year      odometer           lat          long  \
# count  1.723065e+06  1.723065e+06  1.723065e+06  1.723065e+06  1.723065e+06
# mean   1.075540e+05  2.004849e+03  1.114655e+05  3.878195e+01 -9.371198e+01
# std    1.004439e+07  1.206625e+01  1.122891e+05  5.976412e+00  1.696519e+01
# min    1.000000e+00  3.020000e+02  0.000000e+00 -8.481005e+01 -1.000000e+03
# 25%    3.295000e+03  2.002000e+03  8.433900e+04  3.491900e+01 -1.058010e+02
# 50%    7.000000e+03  2.007000e+03  1.070000e+05  3.940989e+01 -8.824070e+01
# 75%    1.499900e+04  2.012000e+03  1.299350e+05  4.255459e+01 -8.102650e+01
# max    2.068627e+09  2.019000e+03  1.000000e+07  9.000000e+01  1.397061e+02
#
#         county_fips    state_fips       weather
# count  1.723065e+06  1.723065e+06  1.723065e+06
# mean   2.845069e+04  2.836650e+01  5.375991e+01
# std    1.577813e+04  1.575661e+01  7.665047e+00
# min    1.001000e+03  1.000000e+00  2.900000e+01
# ...

# %%
data_numerical = (data_numerical - data_numerical.mean(axis = 0))/data_numerical.std(axis = 0)

# %%
data_numerical.describe()
# Out:
#               price          year      odometer           lat          long  \
# count  1.723065e+06  1.723065e+06  1.723065e+06  1.723065e+06  1.723065e+06
# mean  -5.914525e-17 -1.777030e-14  1.452517e-14 -2.637945e-12  4.956968e-12
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.070777e-02 -1.411249e+02 -9.926651e-01 -2.067996e+01 -5.342043e+01
# 25%   -1.037983e-02 -2.360927e-01 -2.415770e-01 -6.463663e-01 -7.125777e-01
# 50%   -1.001097e-02  1.782862e-01 -3.976750e-02  1.050695e-01  3.225003e-01
# 75%   -9.214603e-03  5.926651e-01  1.644821e-01  6.312551e-01  7.477356e-01
# max    2.059378e+02  1.172796e+00  8.806319e+01  8.570032e+00  1.375864e+01
#
#         county_fips    state_fips       weather
# count  1.723065e+06  1.723065e+06  1.723065e+06
# mean   1.466954e-13  9.814416e-14  7.654956e-13
# std    1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.739731e+00 -1.736826e+00 -3.230237e+00
# ...

# %% [markdown]
# # Соединяем все в одну таблицу

# %%
data = pd.concat((data_numerical, data_categorical), axis = 1)
print(data.shape)
# Out:
# (1723065, 26)

# %%
data.describe()
# Out:
#               price          year      odometer           lat          long  \
# count  1.723065e+06  1.723065e+06  1.723065e+06  1.723065e+06  1.723065e+06
# mean  -5.914525e-17 -1.777030e-14  1.452517e-14 -2.637945e-12  4.956968e-12
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.070777e-02 -1.411249e+02 -9.926651e-01 -2.067996e+01 -5.342043e+01
# 25%   -1.037983e-02 -2.360927e-01 -2.415770e-01 -6.463663e-01 -7.125777e-01
# 50%   -1.001097e-02  1.782862e-01 -3.976750e-02  1.050695e-01  3.225003e-01
# 75%   -9.214603e-03  5.926651e-01  1.644821e-01  6.312551e-01  7.477356e-01
# max    2.059378e+02  1.172796e+00  8.806319e+01  8.570032e+00  1.375864e+01
#
#         county_fips    state_fips       weather
# count  1.723065e+06  1.723065e+06  1.723065e+06
# mean   1.466954e-13  9.814416e-14  7.654956e-13
# std    1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.739731e+00 -1.736826e+00 -3.230237e+00
# ...

# %% [markdown]
# # X и y

# %%
X = data.drop(('url'), axis = 1) # выбрасываем столбец 'url'
y = data['url']
feature_names = X.columns

# %%
type(feature_names)
# Out:
# pandas.core.indexes.base.Index

# %%
feature_names
# Out:
# Index(['price', 'year', 'odometer', 'lat', 'long', 'county_fips', 'state_fips',
#        'weather', 'city', 'manufacturer', 'make', 'condition', 'cylinders',
#        'fuel', 'title_status', 'transmission', 'vin', 'drive', 'size', 'type',
#        'paint_color', 'image_url', 'county_name', 'state_code', 'state_name'],
#       dtype='object')

# %%
print(X.shape)
print(y.shape)
N, d = X.shape
# Out:
# (1723065, 25)
# (1723065,)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 1206145 516920

# %%
1206145+516920
# Out:
# 1723065
